# 45  27-Dec-17  162.01  164.84  162.84  163.84     160.84  535528
# 46  26-Dec-17  162.02  160.99  158.99  159.99     156.99  564657
# 47  22-Dec-17  159.01  163.14  161.14  162.14     159.14  583549
# 48  21-Dec-17  158.50  159.88  157.88  158.88     155.88  572562
# 49  20-Dec-17  155.50  158.90  156.90  157.90     154.90  548832
# 50  19-Dec-17  155.76  155.87  153.87  154.87     151.87  561698
# 51  18-Dec-17  157.00  157.06  155.06  156.06     153.06  528751
# 52  15-Dec-17  156.50  157.70  155.70  156.70     153.70  552507
# 53  14-Dec-17  156.75  157.31  155.31  156.31     153.31  577904
# 54  13-Dec-17  159.25  158.08  156.08  157.08     154.08  579790
# 55  12-Dec-17  159.00  160.03  158.03  159.03     156.03  535570
# 56  11-Dec-17  154.60  159.02  157.02  158.02     155.02  561954

# %%
print(fb.head())
# Out:
#         DATE    OPEN    HIGH     LOW   CLOSE  ADJ CLOSE  VOLUME
# 0   1-Mar-18  163.20  164.24  162.24  163.24     160.24  525000
# 1  28-Feb-18  162.10  164.22  162.22  163.22     160.22  566768
# 2  27-Feb-18  161.99  163.31  161.31  162.31     159.31  586657
# 3  26-Feb-18  165.30  162.92  160.92  161.92     158.92  585525
# 4  23-Feb-18  166.01  165.34  163.34  164.34     161.34  553461

# %%
#It is your turn to import Microsoft's stock data - "microsoft.csv", which is located in the same folder of facebook.csv
#Replace "None" with your code
ms = pd.read_csv("microsoft.csv")

# %%
# print head of ms, 1 line
print(ms.head())
# Out:
#         DATE    OPEN    HIGH     LOW   CLOSE  ADJ CLOSE    VOLUME
# 0   1-Mar-18  204.66  205.99  203.99  204.99     201.99  645600.0
# 1  28-Feb-18  204.99  207.55  205.55  206.55     203.55  710920.0
# 2  27-Feb-18  206.55  207.65  205.65  206.65     203.65  728715.0
# 3  26-Feb-18  206.65  207.25  205.25  206.25     203.25  661997.0
# 4  23-Feb-18  206.25  207.88  205.88  206.88     203.88  677190.0

# %% [markdown]
# ** Expected Output: **

# %% [markdown]
# <tr>
#     <th>Date</th>
#     <th>Open</th>
#     <th>High</th>
#     <th>Low</th>
#     <th>Close</th>
#     <th>Adj Close</th>
#     <th>Volume</th>
# </tr>
# <tr>
#     <td>2014-12-31</td>
#     <td>46.730000</td>
#     <td>47.439999</td>
#     <td>46.450001</td>
#     <td>46.450001</td>
#     <td>42.848763</td>
#     <td>21552500</td>
# </tr>
# <tr>
#     <td>2015-01-02</td>
#     <td>46.660000</td>
#     <td>47.419998</td>
#     <td>46.540001</td>
#     <td>46.759998</td>
#     <td>43.134731</td>
#     <td>27913900</td>
# </tr>
# <tr>
#     <td>2015-01-05</td>
#     <td>46.369999</td>
#     <td>46.730000</td>
#     <td>46.250000</td>
#     <td>46.330002</td>
#     <td>42.738068</td>
#     <td>39673900</td>
# </tr>
# <tr>
#     <td>2015-01-06</td>
#     <td>46.380001</td>
#     <td>46.750000</td>
#     <td>45.540001</td>
#     <td>45.650002</td>
#     <td>42.110783</td>
#     <td>36447900</td>
# </tr>
# <tr>
#     <td>2015-01-07</td>
#     <td>45.980000</td>
#     <td>46.459999</td>
#     <td>45.490002</td>
#     <td>46.230000</td>
#     <td>42.645817</td>
#     <td>29114100</td>
# </tr>

# %% [markdown]
# ## Show the size of a DataFrame using "Shape"

# %%
print(fb.shape)
# Out:
# (57, 7)

# %%
# print the shape of ms, 1 line
print(ms.shape)
# Out:
# (61, 7)

# %% [markdown]
# ## Show summary statistics of a DataFrame

# %%
# print summary statistics of Facebook
print(fb.describe())
# Out:
#              OPEN        HIGH         LOW       CLOSE   ADJ CLOSE  \
# count   57.000000   57.000000   57.000000   57.000000   57.000000
# mean   165.563158  166.458772  164.458772  165.458772  162.458772
# std      5.030886    4.752808    4.752808    4.752808    4.752808
# min    154.600000  155.870000  153.870000  154.870000  151.870000
# 25%    162.100000  163.790000  161.790000  162.790000  159.790000
# 50%    166.250000  166.880000  164.880000  165.880000  162.880000
# 75%    169.720000  170.140000  168.140000  169.140000  166.140000
# max    175.050000  174.840000  172.840000  173.840000  170.840000
#
#               VOLUME
# count      57.000000
# mean   558257.385965
# std     18910.969832
# min    525000.000000
# 25%    543564.000000
# 50%    560502.000000
# 75%    574802.000000
# max    588443.000000

# %%
# print summary statistics of Microsoft
print(ms.describe())
# Out:
#              OPEN        HIGH         LOW       CLOSE   ADJ CLOSE  \
# count   57.000000   57.000000   57.000000   57.000000   57.000000
# mean   205.863509  206.886667  204.886667  205.886667  202.886667
# std      0.351332    0.311874    0.311874    0.311874    0.311874
# min    204.660000  205.990000  203.990000  204.990000  201.990000
# 25%    205.660000  206.660000  204.660000  205.660000  202.660000
# 50%    205.920000  206.920000  204.920000  205.920000  202.920000
# 75%    206.050000  207.050000  205.050000  206.050000  203.050000
# max    206.880000  207.880000  205.880000  206.880000  203.880000
#
#               VOLUME
# count      57.000000
# mean   706865.719298
# std     36189.915799
# min    645600.000000
# 25%    676354.000000
# 50%    708491.000000
# 75%    740017.000000
# max    763011.000000

# %% [markdown]
# ## Locate a particular row of data using "Selection by label"

# %%
# select all the price information of Facebook in 2016.
fb_2018 = fb.loc['1-Mar-18':'23-Feb-18']

# %%
# print the price of Facebook on '2015-03-16'
print(fb_2015.get_loc['2015-03-16'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-1a64060f426f> in <module>
#       1 # print the price of Facebook on '2015-03-16'
# ----> 2 print(fb_2015.get_loc['2015-03-16'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'get_loc'

# %%
# select all the price information of Microsoft in 2016.
ms_2018 = fb.loc["1":"5"]

# %%
# print the price of Microsoft on '2016-03-16'
print(ms_2018.get_loc["1"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-c2a66bca7acb> in <module>
#       1 # print the price of Microsoft on '2016-03-16'
# ----> 2 print(ms_2018.get_loc["1"])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'get_loc'

# %% [markdown]
# ** Expected Output: **

# %% [markdown]
# <tr>
#     <td>Open</td>
#     <td>5.345000e+01</td>
# </tr>
# <tr>
#     <td>High</td>
#     <td>5.460000e+01</td>
# </tr>
# <tr>
#     <td>Low</td>
#     <td>5.340000e+01</td>
# </tr>
# <tr>
#     <td>Close</td>
#     <td>5.435000e+01</td>
# </tr>
# <tr>
#     <td>Adj Close</td>
#     <td>5.187095e+01</td>
# </tr>
# <tr>
#     <td>Volume</td>
#     <td>3.169170e+07</td>
# </tr>

# %% [markdown]
# ## Locate a particular row of data using "Selection by position"

# %%
# print the opening price of the first row
print(fb.iloc[0, 0])
# Out:
# 20.4

# %%
# print the opening price of the last row
print(ms.iloc[0, 0])
# Out:
# 46.73

# %% [markdown]
# ** Expected Output: ** 90.559998

# %% [markdown]
# ## Plot the stock data using plot() method

# %%
plt.figure(figsize=(10, 8))
fb['CLOSE'].plot()
plt.show()

# %%
plt.figure(figsize=(10, 8))
# plot only the Close price of 2016 of Microsoft, 1 line 
ms['CLOSE'].plot()
plt.show()

# %% [markdown]
# ** Expected Ouput: **

# %% [markdown]
# <img src="MS2016.png">
